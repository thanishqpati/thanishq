# %% [markdown]
# <a href="https://colab.research.google.com/github/thanishqpati/thanishq/blob/main/scratchpad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re

text = "My phone number is 9949738260 and my email is rangaro123@gmail.com"

# Find phone numbers (10 digits)
phone_pattern = r"\d{10}"
phone = re.search(phone_pattern, text)

# Find email
email_pattern = r"\w+@\w+\.\w+"
email = re.search(email_pattern, text)

if phone:
    print("Phone Number Found:", phone.group())

if email:
    print("Email Found:", email.group())
# Out:
# Phone Number Found: 9949738260
# Email Found: rangaro123@gmail.com
